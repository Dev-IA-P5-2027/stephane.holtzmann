# %% [markdown]
# **K-Means**

# %%
import matplotlib.pyplot as plt
from kneed import KneeLocator
from sklearn.datasets import make_blobs
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
from sklearn.preprocessing import StandardScaler

from sklearn.cluster import DBSCAN
from sklearn.datasets import make_moons
from sklearn.metrics import adjusted_rand_score

# %%
features, true_labels = make_blobs(
    n_samples = 200,
    centers = 3,
    cluster_std = 2.75,
    random_state = 42
)
# En général, il vaut mieux utiliser .random_staterandom_stateNone

# %%
print(features[:5])
true_labels[:5]
# Out:
# [[  9.77075874   3.27621022]
#  [ -9.71349666  11.27451802]
#  [ -6.91330582  -9.34755911]
#  [-10.86185913 -10.75063497]
#  [ -8.50038027  -4.54370383]]
# array([1, 0, 2, 2, 2])

# %% [markdown]
# Mise à l'échelle

# %%
scaler = StandardScaler()
scaled_features = scaler.fit_transform(features)
print(scaled_features[:5])
# Out:
# [[ 2.13082109  0.25604351]
#  [-1.52698523  1.41036744]
#  [-1.00130152 -1.56583175]
#  [-1.74256891 -1.76832509]
#  [-1.29924521 -0.87253446]]

# %% [markdown]
# Instance de la classe

# %%
kmeans = KMeans(
    init = "random",
    n_clusters = 3,
    n_init = 10,
    max_iter = 300,
    random_state = 42
)

# %% [markdown]
# Ajustement pour les données

# %%
kmeans.fit(scaled_features)
# Out:
# KMeans(init='random', n_clusters=3, n_init=10, random_state=42)

# %% [markdown]
# Stats / Métriques

# %%
# Valeur SSE la plus basse
kmeans.inertia_

# Endroit final des centroids
kmeans.cluster_centers_

# Nbr d'itération requit pour converger
kmeans.n_iter_
# Out:
# 10

# %%
kmeans.labels_[:5]
# Out:
# array([0, 1, 2, 2, 2], dtype=int32)

# %% [markdown]
# Méthode Elbow

# %%
kmeans_kwargs = {
    "init" : "random",
    "n_init" : 10,
    "max_iter" : 300,
    "random_state" : 42,
}

# Liste donne la SSE pour chaque k
sse = []
for k in range(1, 11):
    kmeans = KMeans(n_clusters=k, **kmeans_kwargs)
    kmeans.fit(scaled_features)
    sse.append(kmeans.inertia_)

# %% [markdown]
# Graphique SSE pour méthode Elbow

# %%
plt.style.use("fivethirtyeight")
plt.plot(range(1, 11), sse)
plt.xticks(range(1, 11))
plt.xlabel("Number of Clusters")
plt.ylabel("SSE")
plt.show()

# %% [markdown]
# Pour trouver le point du coude sur la courbe on utilise kneed

# %%
kl = KneeLocator(
    range(1, 11), sse, curve="convex", direction="decreasing"
)

# %% [markdown]
# Calculer Coefficient de Silhouette

# %%
# Liste contenant les coefficients de silhouette pour chaque k
silhouette_coefficients = []

# Pour le coefficient de silhouette on commence avec 2 clusters
for k in range(2, 11):
    kmeans = KMeans(n_clusters=k, **kmeans_kwargs)
    kmeans.fit(scaled_features)
    score = silhouette_score(scaled_features, kmeans.labels_)
    silhouette_coefficients.append(score)

# %% [markdown]
# Graphique pour les scores moyens de silouhettes pour chaque (meilleur choix = score max :kk3)

# %%
plt.style.use("fivethirtyeight")
plt.plot(range(2, 11), silhouette_coefficients)
plt.xticks(range(2, 11))
plt.xlabel("Number of Clusters")
plt.ylabel("Silhouette Coefficient")
plt.show()

# %% [markdown]
# Générer des données synthétiques en forme de croissants make_moons()

# %%
features, true_labels = make_moons(
    n_samples=250, noise=0.05, random_state=42
)
scaled_features = scaler.fit_transform(features)

# %% [markdown]
# Ajuster k-means et DBSCAN  aux nouvelles données pour visualiser les perfs en tracant les affectations
# de cluster avec matplotlib

# %%
# Instance de k-means et DBSCAN
kmeans = KMeans(n_clusters=2)
dbscan = DBSCAN(eps=0.3)

# Entrainer l'algo avec les features
kmeans.fit(scaled_features)
dbscan.fit(scaled_features)

# Ordonner les silhouettes pour chaque algo 
kmeans_silhouette = round(silhouette_score(
    scaled_features, kmeans.labels_
), 2)
dbscan_silhouette = round(silhouette_score(
    scaled_features, dbscan.labels_
), 2)

# %%
kmeans_silhouette
# Out:
# 0.5

# %%
dbscan_silhouette
# Out:
# 0.38

# %% [markdown]
# Graphique silhouette

# %%
# Plot the data and cluster silhouette comparison
fig, (ax1, ax2) = plt.subplots(
    1, 2, figsize=(8, 6), sharex=True, sharey=True
)
fig.suptitle(f"Clustering Algorithm Comparison: Crescents", fontsize=16)
fte_colors = {
   0: "#008fd5",
   1: "#fc4f30",
   }
   # The k-means plot
km_colors = [fte_colors[label] for label in kmeans.labels_]
ax1.scatter(scaled_features[:, 0], scaled_features[:, 1], c=km_colors)
ax1.set_title(
       f"k-means\nSilhouette: {kmeans_silhouette}", fontdict={"fontsize": 12}
   )

   # The dbscan plot
db_colors = [fte_colors[label] for label in dbscan.labels_]
ax2.scatter(scaled_features[:, 0], scaled_features[:, 1], c=db_colors)
ax2.set_title(
       f"DBSCAN\nSilhouette: {dbscan_silhouette}", fontdict={"fontsize": 12}
   )
plt.show()

# %% [markdown]
# Comparaison résultats clustering dbscan et k-means avec métriques ARI

# %%
ari_kmeans = adjusted_rand_score(true_labels, kmeans.labels_)
ari_dbscan = adjusted_rand_score(true_labels, dbscan.labels_)

# %%
round(ari_kmeans, 2)
# Il y a un erreur jsp pourquoi
# Out:
# 0.46

# %%
round(ari_dbscan, 2)
# Out:
# 1.0

# %% [markdown]
# Pipeline de Clustering k-means

# %%
import tarfile
import urllib 

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
from sklearn.metrics import silhouette_score, adjusted_rand_score
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import LabelEncoder, MinMaxScaler

# %%
uci_tcga_url = "https://archive.ics.uci.edu/ml/machine-learning-databases/00401/"
archive_name = "TCGA-PANCAN-HiSeq-801x20531.tar.gz"
# Build the url
full_download_url = urllib.parse.urljoin(uci_tcga_url, archive_name)
# Download the file
r = urllib.request.urlretrieve (full_download_url, archive_name)
# Extract the data from the archive
tar = tarfile.open(archive_name, "r:gz")
tar.extractall()
tar.close()

# %%
datafile = "TCGA-PANCAN-HiSeq-801x20531/data.csv"
labels_file = "TCGA-PANCAN-HiSeq-801x20531/labels.csv"
data = np.genfromtxt(
    datafile,
    delimiter=",",
    usecols=range(1, 20532),
    skip_header=1
)
true_label_names = np.genfromtxt(
    labels_file,
    delimiter=",",
    usecols=(1,),
    skip_header=1,
    dtype="str"
)

# %%
data[:5, :3]
# Out:
# array([[0.        , 2.01720929, 3.26552691],
#        [0.        , 0.59273209, 1.58842082],
#        [0.        , 3.51175898, 4.32719872],
#        [0.        , 3.66361787, 4.50764878],
#        [0.        , 2.65574107, 2.82154696]])

# %%
true_label_names[:5]
# Out:
# array(['PRAD', 'LUAD', 'PRAD', 'PRAD', 'BRCA'], dtype='<U4')

# %%
label_encoder = LabelEncoder()
true_labels = label_encoder.fit_transform(true_label_names)
true_labels[:5]
# Out:
# array([4, 3, 4, 4, 0])

# %%
label_encoder.classes_
# Out:
# array(['BRCA', 'COAD', 'KIRC', 'LUAD', 'PRAD'], dtype='<U4')

# %%
n_clusters = len(label_encoder.classes_)

# %% [markdown]
# malédiction de la dimensionnalité

# %%
preprocessor = Pipeline(
    [
        ("scaler", MinMaxScaler()),
        ("pca", PCA(n_components=2, random_state=42)),
    ]
)

# %%
clusterer = Pipeline(
    [
        (
            "kmeans",
            KMeans(
                n_clusters=n_clusters,
                init="k-means++",
                n_init=50,
                max_iter=500,
                random_state=42,
            ),
        ),
    ]
)

# %%
pipe = Pipeline(
    [
        ("preprocessor", preprocessor),
        ("clusterer", clusterer)
    ]
)

# %%
pipe.fit(data)
# Out:
# Pipeline(steps=[('preprocessor',
#                  Pipeline(steps=[('scaler', MinMaxScaler()),
#                                  ('pca',
#                                   PCA(n_components=2, random_state=42))])),
#                 ('clusterer',
#                  Pipeline(steps=[('kmeans',
#                                   KMeans(max_iter=500, n_clusters=5, n_init=50,
#                                          random_state=42))]))])

# %%
preprocessed_data = pipe["preprocessor"].transform(data)
predicted_labels = pipe["clusterer"]["kmeans"].labels_
silhouette_score(preprocessed_data, predicted_labels)
# Out:
# 0.5118775528450286

# %%
adjusted_rand_score(true_labels, predicted_labels)
# Out:
# 0.722276752060253

# %%
pcadf = pd.DataFrame(
    pipe["preprocessor"].transform(data),
    columns=["component_1", "component_2"],
)

pcadf["predicted_cluster"] = pipe["clusterer"]["kmeans"].labels_
pcadf["true_label"] = label_encoder.inverse_transform(true_labels)

plt.style.use("fivethirtyeight")
plt.figure(figsize=(8, 8))

scat = sns.scatterplot(
    x="component_1",
    y="component_2",
    s=50,
    data=pcadf,
    hue="predicted_cluster",
    style="true_label",
    palette="Set2",
)

scat.set_title(
    "Clustering results from TCGA Pan-Cancer\nGene Expression Data"
)
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.0)

plt.show()

# %%
# Empty lists to hold evaluation metrics
silhouette_scores = []
ari_scores = []
for n in range(2, 11):
    # This set the number of components for pca,
    # but leaves other steps unchanged
    pipe["preprocessor"]["pca"].n_components = n
    pipe.fit(data)
    silhouette_coef = silhouette_score(
        pipe["preprocessor"].transform(data),
        pipe["clusterer"]["kmeans"].labels_,
    )
    ari = adjusted_rand_score(
        true_labels,
        pipe["clusterer"]["kmeans"].labels_,
    )
    # Add metrics to their lists
    silhouette_scores.append(silhouette_coef)
    ari_scores.append(ari)

# %%
plt.style.use("fivethirtyeight")
plt.figure(figsize=(6, 6))
plt.plot(
    range(2, 11),
    silhouette_scores,
    c="#008fd5",
    label="Silhouette Coefficient",
)
plt.plot(range(2, 11), ari_scores, c="#fc4f30", label="ARI")

plt.xlabel("n_components")
plt.legend()
plt.title("Clustering Performance as a Function of n_components")
plt.tight_layout()
plt.show()
